# %% [markdown]
# <a href="https://colab.research.google.com/github/DevNathancod/Desenvolvimento-Web-TDS_IFB-Nathanael/blob/main/atividade2_python_TDS_NathanaelRocha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nome: Nathanael Cruz
#
# Curso e disciplina: Tecnico em Desenvolvimento e Desenvolvimento de Sistemas para Web 2025/2
#
# Exercicio de Lista de Exercícios N° 02

# %%
# 1. Elabore um programa que solicite ao usuário um número real e ao final imprima na tela se o
# número informado é maior que 10 (dez)
num = float(input("escolhe um numero real: "))
if num > 10:
  print("Numero maior que 10:", num)
else:
  print("Numero menor que 10:", num)
# Out:
# escolhe um numero real: 5.5
# Numero menor que 10: 5.5

# %%
# 2. Escreva um programa que solicite ao usuário um número real e ao final imprima na tela se
# o número informado é maior ou igual a dez ou menor que 10 (dez)
num2 = float(input("Escolhe um numero real: "))
if num2 >= 10:
  print("O numero é maior ou igual a 10:", num2)
else:
  print("O numero é menor ou igual a 10:", num2)
# Out:
# Escolhe um numero real: 9.9
# O numero é menor ou igual a 10: 9.9

# %%
# 3. Elabore um algoritmo que solicite ao usuário um número real e ao final imprima na tela se o
# número informado é maior que dez, se é menor que dez, ou se é igual a dez
num3 = float(input("Digite seu numero real: "))
if num3 > 10:
  print("o numero maior que 10.")
elif num3 < 10:
  print("o numero menor que 10.")
else:
  print("o numero é igual a 10.")
# Out:
# Digite seu numero real: 9
# o numero menor que 10

# %%
# 4. Elabore um algoritmo que solicite ao usuário um número real e ao final imprima na tela se o
# número informado é positivo, negativo ou nulo (zero)
num4 = float(input("Digite numero real: "))
if num4 > 0:
  print("O numero é positivo")
elif num4 < 0:
  print("O numero é negativo")
else:
  print("O numero é nulo (zero)")
# Out:
# Digite numero real: -1
# O numero é negativo

# %%
# 5. Elabore um algoritmo que leia um número inteiro e imprima uma das mensagens: é múltiplo
# de 3, ou, não é múltiplo de 3
num5 = int(input("Digite numero inteiro: "))
if num5 % 3 == 0:
  print("É multiplo de 3.")
else:
  print("não é multiplo de 3.")

# %%
# 6. Refazer o exercício anterior, solicitando antes o múltiplo a ser testado

# %%
# 7. Desenvolva um algoritmo que classifique um número inteiro fornecido pelo usuário como
# par ou ímpar
num7 = int(input("Jogo de impar ou par: "))
if num7 % 2 == 0:
  print("Seu numero é par")
else:
  print("Seu numero é impar")

# %%
# 8. Elabore um algoritmo que leia um número, e se ele for maior do que 20, imprimir a metade
# desse número, caso contrário, imprimir o dobro do número
num8 = int(input("Digite seu numero: "))
if num8 > 20:
  num8 = num8 / 2
  print("Numero maior que 20, assim metade desse numero é:", num8)
else:
  num8 = num8 * 2
  print("Numero é 20 ou menor, assim dobro desse numero é:", num8)
# Out:
# Digite seu numero: 8
# Numero é 20 ou menor, assim dobro desse numero é: 16

# %%
# 9. Elabore um algoritmo que leia dois números inteiros e realize a adição; caso o resultado
# seja maior que 10, imprima o quadrado do resultado, caso contrário, imprima a metade dele
num9 = int(input("Digite seu primeiro numero: "))
nume9 = int(input("Digite seu segundo numero: "))
resultado = num9 + nume9
if resultado > 10:
  print("Numero maior é:", resultado **2)
else:
  resultado = resultado / 2
  print("Mestade de numero:", resultado)
# Out:
# Digite seu primeiro numero: 2
# Digite seu segundo numero: 2
# Mestade de numero: 2.0

# %%
# 10. O sistema de avaliação de determinada disciplina é composto por três provas. A primeira
# prova tem peso 2, a segunda tem peso 3 e a terceira tem peso 5. Considerando que a
# média para aprovação é 6.0, faça um algoritmo para calcular a média final de um aluno
# desta disciplina e dizer se o aluno foi aprovado ou não
nota2 = float(input("Qual é sua nota de primeira prova que tem peso 2: "))
nota3 = float(input("Qual é sua nota de segunda prova que tem peso 3: "))
nota5 = float(input("Qual é sua nota de terceira prova que tem peso 5: "))
notamedia = (nota2 * 2+ nota3 * 3 + nota5 * 5)/10
if notamedia > 6.0:
  print("Sua nota foi aprovada, sua nota é:", notamedia)
else:
  print("Sua nota foi reprovada, sua nota é:", notamedia)
# Out:
# Qual é sua nota de primeira prova que tem peso 2: 7
# Qual é sua nota de segunda prova que tem peso 3: 5
# Qual é sua nota de terceira prova que tem peso 5: 6
# Sua nota foi reprovada, sua nota é: 5.9

# %%
# 11. Elabore um algoritmo que leia o nome e o peso de duas pessoas e imprima o nome da
# pessoa mais pesada

# %%
# 12. Elabore um algoritmo que indique se um número digitado está compreendido entre 20 e
# 90, ou não
num12 = int(input("Digite o numero: "))
if 20 < num12 < 90:
  print("o numero está entre 20 a 90")
else:
  print("o numero não está entre 20 a 90")
# Out:
# Digite o numero: 3
# o numero não está entre 20 a 90

# %%
# 13. Elabore um algoritmo que leia dois números e imprima qual é maior, qual é menor, ou se
# são iguais
num13 = int(input("Escolhe seu primeiro numero: "))
nume13 = int(input("Escolhe seu segundo numero: "))
if num13 > nume13:
  print("Numero é maior:", nume13)
  print("Numero é maior:", num13)
elif num13 < nume13:
  print("Numero é menor:", num13)
  print("Numero é menor:", nume13)
else:
  print("Ambos são iguais")

# %%
# 14. Escreva um programa em linguagem C que solicite ao usuário a média para aprovação
# em um curso e em seguida solicite ao usuário o nome, sexo e as 03 notas do aluno e ao
# final imprima a frase: "O aluno XXXXX foi aprovado com media YY" considerando o gênero
# do(a) aluno(a) e se foi aprovado(a) ou reprovado(a)
