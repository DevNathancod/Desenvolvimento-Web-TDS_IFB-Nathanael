# %% [markdown]
# <a href="https://colab.research.google.com/github/DevNathancod/Desenvolvimento-Web-TDS_IFB-Nathanael/blob/main/atividade1_python_TDS_NathanaelRocha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nome: Nathanael Cruz
#
# Curso e disciplina: Tecnico em Desenvolvimento e Desenvolvimento de Sistemas para Web 2025/2
#
# Exercicio de Lista de Exercícios N° 01

# %%
# 1. Escreva um programa que apresente na tela a frase: "Meu primeiro programa!!!"
print("Meu primeiro programa!!!")
# Out:
# Meu primeiro programa!!!

# %%
# 2. Escreva um programa que solicite ao usuário um número inteiro e ao final apresente na tela
# o número informado pelo usuário do programa

numint = int(input("Digite seu numero inteiro: "))
print("Seu numero é:", numint)
# Out:
# Digite seu numero inteiro: 10
# seu numero é: 10

# %%
# 3. Escreva um programa que solicite ao usuário um número inteiro e ao final apresente na tela
# o número informado da seguinte forma: "Foi informado o valor: X"
numin = int(input("Digite seu numero real: "))
print("Foi informado o valor", numin)
# Out:
# Digite seu numero inteiro: 1000
# Foi informado o valor 1000

# %%
# 4. Escreva um programa que solicite ao usuário dois números inteiros e ao final apresente na
# tela os dois números informados da seguinte forma: "Voce informou os numeros X e Y"
numint1 = int(input("Digite seu primeiro numero inteiro: "))
numint2 = int(input("Digite seu segundo numero inteiro: "))
print("Seus numeros apresentam:", numint1,"e", numint2)
# Out:
# Digite seu primeiro numero inteiro: 12
# Digite seu segundo numero inteiro: 12
# Seus numeros apresentam: 12 e 12

# %%
# 5. Escreva um programa que solicite ao usuário um número real e ao final apresente na tela o
# número informado formatado com duas casas decimais da seguinte forma: "Voce informou o numero X.YY"
numreal = float(input("Digite seu numero real: "))
print("Voce informou o numero:", numreal)
# Out:
# Digite seu numero real: 2.12
# Voce informou o numero: 2.12

# %%
# 6. Escreva um programa que solicite ao usuário a temperatura em graus Celsius e ao final
# apresente a temperatura correspondente em graus Farenheit. F = Celsius * 1.8 + 32
temp_celsius = float(input("Digite o numero de temperatura em celsuis: "))
temp_faren = temp_celsius * 1.8 + 32
print("Grau de temperatura Farenheit é:", temp_faren)
# Out:
# Digite o numero de temperatura em celsuis: 40
# Grau de temperatura Farenheit é: 104.0

# %%
# 7. Escreva um programa que solicite ao usuário um número inteiro e um número real e ao final
# apresente na tela os dois números informados formatando com duas casas decimais
# somente o número real da seguinte forma: "Voce informou os numeros N e X.YY"
numteiro = int(input("Digite seu numero inteiro: "))
numflo = float(input("Digite seu numero real: "))
print("Voce informou os numeros:", numteiro, "e", numflo)
# Out:
# Digite seu numero inteiro: 3
# Digite seu numero real: 3.98
# Voce informou os numeros: 3 e 3.98

# %%
# 8. Escreva um programa que solicite ao usuário a primeira letra de seu nome e ao final
# apresente na tela a letra informada pelo usuário da seguinte forma: "Voce digitou w"
letra = input("qual é sua primeira letra de seu numero: ")
print("Você digitou", letra)
# Out:
# qual é sua primeira letra de seu numero: k
# Você digitou k

# %%
# 9. Escreva um programa que solicite ao usuário o nome de sua cor preferida e ao final
# apresente na tela a cor informada pelo usuário da seguinte forma: "Voce gosta da cor AAA"
cor = str(input("O nome de sua cor preferida? "))
print("Você gosta da cor", cor)
# Out:
# O nome de sua cor preferida? Amarela
# Você gosta da cor Amarela

# %%
# 10. Escreva um programa que solicite ao usuário o nome de uma verdura e uma fruta de sua
# preferencia e ao final apresente na tela as informações digitadas pelo usuário da seguinte
# forma: "Voce gosta de AAAAAAA e BBBBBBB"
verdura = str(input("O nome de uma verdura em preferida? "))
fruta = str(input("E o nomde de uma fruta em preferencia?" ))
print("Você gosta de", verdura, "e", fruta)
# Out:
# O nome de uma verdura em preferida? alface
# E o nomde de uma fruta em preferencia?pessego
# Você gosta de alface e pessego

# %%
# 11. Elabore um algoritmo que solicite ao usuário um número real e ao final imprima na tela o
# numero informado e na linha de baixo o dobro deste número da seguinte forma:
# Numero -> X
# Dobro deste numero -> Y
numre = float(input("Digite seu numero real: "))
dobro = numre * 2
print("Numero -->", numre, "\nDobro deste numero -->", dobro)
# Out:
# Digite seu numero real: 4.5
# Numero --> 4.5
# Dobro deste numero --> 9.0

# %%
#12. Reescrever o programa anterior apresentando o quadrado e o cubo do número informado
quadrado = float(input("qual é numero de quadrado: "))
cubo = float(input("qual é numero de cubo: "))
print( "Numero de quadrado:", quadrado,"\nNumero de cubo:", cubo)
# Out:
# qual é numero de quadrado: 5.5
# qual é numero de cubo: 5.6
# Numero de quadrado 5.5
# Numero de cubo: 5.6

# %%
# 13. Escreva um programa que solicite ao usuário dois números inteiros e ao final apresente
# na tela a soma dos dois números informados da seguinte forma: "O numeros N e X
# somados correspondem a Y"
n = int(input('Digite primeiro numero inteiro: '))
x = int(input('Digite segundo numero inteiro: '))
y = x + n
print("soma de dois numeros em total:", y)
# Out:
# Digite primeiro numero inteiro: 5
# Digite segundo numero inteiro: 4
# soma de dois numeros em total: 9

# %%
# 14. Escreva um programa que solicite ao usuário dois números reais e ao final apresente na
# tela o produto dos dois números informados da seguinte forma: "O produto dos numeros N
# e X corresponde a Y"
nfloat = float(input('Digite primeiro numero real: '))
xfloat = float(input('Digite segundo numero real: '))
yfloat = xfloat + nfloat
print("soma de dois numeros em total:", yfloat)
# Out:
# Digite primeiro numero real: 8.76
# Digite segundo numero real: 34.05
# soma de dois numeros em total: 42.809999999999995

# %%
# 15. Refazer o programa 14 realizando as quatro operações aritméticas básicas
nfloat = float(input('Digite primeiro numero real: '))
xfloat = float(input('Digite segundo numero real: '))
yfloat1 = xfloat + nfloat
yfloat2 = xfloat - nfloat
yfloat3 = xfloat / nfloat
yfloat4 = xfloat * nfloat
print("calculo em operaçoôs: soma=", yfloat1, ", subtração =",yfloat2 ,"divisão",yfloat3 ,"multiplicação =",yfloat4)
# Out:
# Digite primeiro numero real: 30.5
# Digite segundo numero real: 90.5
# calculo em operaçoôs: soma= 121.0 , adição = 60.0 divisão 2.9672131147540983 multiplicação = 2760.25
